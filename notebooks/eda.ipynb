# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import suraj_datalab as sd

# %%
# Set the display options to show all columns
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")
ss = pd.read_csv("../input/sample_submission.csv")

train.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    Encroachments  IneffectiveDisasterPreparedness  DrainageSystems  \
# 0              4                                2                5
# 1              6                                9                7
# 2              5                                6                7
# 3              8                                5                2
# 4              3                                5                2
#
#    CoastalVulnerability  Landslides  Watersheds  DeterioratingInfrastructure  \
# 0                     3           3           5                            4
# 1                     2           0           3                            5
# 2                     3           7           5                            6
# 3                     4           7           4                            4
# 4                     2           6           6                            4
#
#    PopulationScore  WetlandLoss  InadequatePlanning  PoliticalFactors  \
# 0                7            5                   7                 3
# 1                3            3                   4                 3
# 2                8            2                   3                 3
# 3                6            5                   7                 5
# 4                1            2                   3                 5
#
#    FloodProbability
# 0             0.445
# 1             0.450
# 2             0.530
# 3             0.535
# 4             0.415

# %%
ss.head()
# Out:
#         id  FloodProbability
# 0  1117957               0.5
# 1  1117958               0.5
# 2  1117959               0.5
# 3  1117960               0.5
# 4  1117961               0.5

# %%
train.isna().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
train.shape
# Out:
# (1117957, 22)

# %%
test.shape
# Out:
# (745305, 21)

# %%
train.drop('id', axis=1, inplace=True)

# %%
train.nunique()
# Out:
# MonsoonIntensity                   17
# TopographyDrainage                 19
# RiverManagement                    17
# Deforestation                      18
# Urbanization                       18
# ClimateChange                      18
# DamsQuality                        17
# Siltation                          17
# AgriculturalPractices              17
# Encroachments                      19
# IneffectiveDisasterPreparedness    17
# DrainageSystems                    18
# CoastalVulnerability               18
# Landslides                         17
# Watersheds                         17
# DeterioratingInfrastructure        18
# PopulationScore                    19
# WetlandLoss                        20
# InadequatePlanning                 17
# PoliticalFactors                   17
# FloodProbability                   83
# dtype: int64

# %%
help(sd)
# Out:
# Help on package suraj_datalab:
#
# NAME
#     suraj_datalab
#
# PACKAGE CONTENTS
#     analyze
#     clean
#     fold_creator
#
# FILE
#     d:\suraj\data science\kaggle\kaggle_env_312\lib\site-packages\suraj_datalab\__init__.py

# %%
help(sd.analyze)
# Out:
# Help on module suraj_datalab.analyze in suraj_datalab:
#
# NAME
#     suraj_datalab.analyze
#
# FUNCTIONS
#     categorical_feature(df, feature, target)
#         Calculate the distribution of a categorical feature in a DataFrame with respect to a target variable.
#         Parameters:
#             df (DataFrame): The input DataFrame.
#             feature (str): The name of the categorical feature.
#             target (str): The name of the target variable.
#         Returns:
#             DataFrame: A DataFrame containing the distribution of the feature, including the total count, total percentage,
#                        percentages for each target class relative to the total, and percentages of each target class within
#                        the feature category.
#         Raises:
#             None
#
#     is_jupyter_notebook()
#         Check if the code is running in a Jupyter notebook environment.
#
#         Returns:
#             bool: True if running in a Jupyter notebook or JupyterLab, False otherwise.
#
#     missing_values(dataframe)
#         Generates a summary of missing values in the dataframe.
#
#         Parameters:
#         dataframe (pd.DataFrame): The input dataframe to analyze.
#
#         Returns:
#         pd.DataFrame: A dataframe containing the count and percentage of missing values,
#                       along with the data type of each column that has missing values.
#
#     numerical_feature(df, feature, target=None, figsize=(15, 6), bins='sturges')
#         Analyzes a numerical feature in a dataframe.
#         Parameters:
#         - df (pandas.DataFrame): The dataframe containing the data.
#         - feature (str): The name of the numerical feature to analyze.
#         - target (str, optional): The name of the target column for grouping the analysis. Default is None.
#         - figsize (tuple, optional): The size of the figure. Default is (15, 6).
#         - bins (int, str, optional): The number of bins for the histogram or the method to calculate it. Default is 'sturges'.
#         Returns:
#         - outliers_df (pandas.DataFrame): A dataframe containing the percentage of outliers in the data.
#         - summary_df (pandas.DataFrame): A dataframe containing the overall statistics, lower outliers statistics, and upper outliers statistics.
#
# FILE
#     d:\suraj\data science\kaggle\kaggle_env_312\lib\site-packages\suraj_datalab\analyze.py

# %%
for col in train.columns:
    outliers, summary = sd.analyze.numerical_feature(df=train, feature=col)
    display(outliers)
    display(summary)
# Out:
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.826865                        0.0                   0.826865
#                                      count       mean       std   min   25%  \
# MonsoonIntensity_Overall         1117957.0   4.921450  2.056387   0.0   3.0
# MonsoonIntensity_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# MonsoonIntensity_Upper_Outliers     9244.0  11.603527  0.980383  11.0  11.0
#
#                                   50%   75%   max
# MonsoonIntensity_Overall          5.0   6.0  16.0
# MonsoonIntensity_Lower_Outliers   NaN   NaN   NaN
# MonsoonIntensity_Upper_Outliers  11.0  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.856473                        0.0                   0.856473
#                                        count       mean       std   min   25%  \
# TopographyDrainage_Overall         1117957.0   4.926671  2.093879   0.0   3.0
# TopographyDrainage_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# TopographyDrainage_Upper_Outliers     9575.0  11.555927  0.931641  11.0  11.0
#
#                                     50%   75%   max
# TopographyDrainage_Overall          5.0   6.0  18.0
# TopographyDrainage_Lower_Outliers   NaN   NaN   NaN
# TopographyDrainage_Upper_Outliers  11.0  12.0  18.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.649207                    0.48365                   2.165557
#                                     count       mean       std   min   25%  \
# RiverManagement_Overall         1117957.0   4.955322  2.072186   0.0   4.0
# RiverManagement_Lower_Outliers     5407.0   0.000000  0.000000   0.0   0.0
# RiverManagement_Upper_Outliers    24210.0  10.580917  0.933980  10.0  10.0
#
#                                  50%   75%   max
# RiverManagement_Overall          5.0   6.0  16.0
# RiverManagement_Lower_Outliers   0.0   0.0   0.0
# RiverManagement_Upper_Outliers  10.0  11.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.525589                   0.476494                   2.049095
#                                   count       mean       std   min   25%  \
# Deforestation_Overall         1117957.0   4.942240  2.051689   0.0   4.0
# Deforestation_Lower_Outliers     5327.0   0.000000  0.000000   0.0   0.0
# Deforestation_Upper_Outliers    22908.0  10.610311  0.956564  10.0  10.0
#
#                                50%   75%   max
# Deforestation_Overall          5.0   6.0  17.0
# Deforestation_Lower_Outliers   0.0   0.0   0.0
# Deforestation_Upper_Outliers  10.0  11.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.821499                        0.0                   0.821499
#                                  count       mean       std   min   25%   50%  \
# Urbanization_Overall         1117957.0   4.942517  2.083391   0.0   3.0   5.0
# Urbanization_Lower_Outliers        0.0        NaN       NaN   NaN   NaN   NaN
# Urbanization_Upper_Outliers     9184.0  11.599085  0.947255  11.0  11.0  11.0
#
#                               75%   max
# Urbanization_Overall          6.0  17.0
# Urbanization_Lower_Outliers   NaN   NaN
# Urbanization_Upper_Outliers  12.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.778384                        0.0                   0.778384
#                                   count       mean       std   min   25%  \
# ClimateChange_Overall         1117957.0   4.934093  2.057742   0.0   3.0
# ClimateChange_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# ClimateChange_Upper_Outliers     8702.0  11.560561  0.903554  11.0  11.0
#
#                                50%   75%   max
# ClimateChange_Overall          5.0   6.0  17.0
# ClimateChange_Lower_Outliers   NaN   NaN   NaN
# ClimateChange_Upper_Outliers  11.0  12.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.781592                   0.525781                   2.255811
#                                 count       mean       std   min   25%   50%  \
# DamsQuality_Overall         1117957.0   4.955878  2.083063   0.0   4.0   5.0
# DamsQuality_Lower_Outliers     5878.0   0.000000  0.000000   0.0   0.0   0.0
# DamsQuality_Upper_Outliers    25219.0  10.617709  0.942963  10.0  10.0  10.0
#
#                              75%   max
# DamsQuality_Overall          6.0  16.0
# DamsQuality_Lower_Outliers   0.0   0.0
# DamsQuality_Upper_Outliers  11.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.812106                        0.0                   0.812106
#                               count       mean       std   min   25%   50%  \
# Siltation_Overall         1117957.0   4.927791  2.065992   0.0   3.0   5.0
# Siltation_Lower_Outliers        0.0        NaN       NaN   NaN   NaN   NaN
# Siltation_Upper_Outliers     9079.0  11.587950  0.935548  11.0  11.0  11.0
#
#                            75%   max
# Siltation_Overall          6.0  16.0
# Siltation_Lower_Outliers   NaN   NaN
# Siltation_Upper_Outliers  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.805577                        0.0                   0.805577
#                                           count       mean       std   min  \
# AgriculturalPractices_Overall         1117957.0   4.942619  2.068545   0.0
# AgriculturalPractices_Lower_Outliers        0.0        NaN       NaN   NaN
# AgriculturalPractices_Upper_Outliers     9006.0  11.521097  0.880758  11.0
#
#                                        25%   50%   75%   max
# AgriculturalPractices_Overall          3.0   5.0   6.0  16.0
# AgriculturalPractices_Lower_Outliers   NaN   NaN   NaN   NaN
# AgriculturalPractices_Upper_Outliers  11.0  11.0  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.785528                   0.494742                   2.290786
#                                   count       mean       std   min   25%  \
# Encroachments_Overall         1117957.0   4.949230  2.083324   0.0   4.0
# Encroachments_Lower_Outliers     5531.0   0.000000  0.000000   0.0   0.0
# Encroachments_Upper_Outliers    25610.0  10.586841  0.946938  10.0  10.0
#
#                                50%   75%   max
# Encroachments_Overall          5.0   6.0  18.0
# Encroachments_Lower_Outliers   0.0   0.0   0.0
# Encroachments_Upper_Outliers  10.0  11.0  18.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0             0.80012                        0.0                    0.80012
#                                                     count       mean  \
# IneffectiveDisasterPreparedness_Overall         1117957.0   4.945239
# IneffectiveDisasterPreparedness_Lower_Outliers        0.0        NaN
# IneffectiveDisasterPreparedness_Upper_Outliers     8945.0  11.566238
#
#                                                      std   min   25%   50%  \
# IneffectiveDisasterPreparedness_Overall         2.078141   0.0   3.0   5.0
# IneffectiveDisasterPreparedness_Lower_Outliers       NaN   NaN   NaN   NaN
# IneffectiveDisasterPreparedness_Upper_Outliers  0.927070  11.0  11.0  11.0
#
#                                                  75%   max
# IneffectiveDisasterPreparedness_Overall          6.0  16.0
# IneffectiveDisasterPreparedness_Lower_Outliers   NaN   NaN
# IneffectiveDisasterPreparedness_Upper_Outliers  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.688833                   0.499304                    2.18953
#                                     count       mean       std   min   25%  \
# DrainageSystems_Overall         1117957.0   4.946893  2.072333   0.0   4.0
# DrainageSystems_Lower_Outliers     5582.0   0.000000  0.000000   0.0   0.0
# DrainageSystems_Upper_Outliers    24478.0  10.625174  0.972683  10.0  10.0
#
#                                  50%   75%   max
# DrainageSystems_Overall          5.0   6.0  17.0
# DrainageSystems_Lower_Outliers   0.0   0.0   0.0
# DrainageSystems_Upper_Outliers  10.0  11.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.913184                        0.0                   0.913184
#                                          count       mean       std   min  \
# CoastalVulnerability_Overall         1117957.0   4.953999  2.088899   0.0
# CoastalVulnerability_Lower_Outliers        0.0        NaN       NaN   NaN
# CoastalVulnerability_Upper_Outliers    10209.0  11.540308  0.896684  11.0
#
#                                       25%   50%   75%   max
# CoastalVulnerability_Overall          3.0   5.0   6.0  17.0
# CoastalVulnerability_Lower_Outliers   NaN   NaN   NaN   NaN
# CoastalVulnerability_Upper_Outliers  11.0  11.0  12.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.792964                        0.0                   0.792964
#                                count       mean       std   min   25%   50%  \
# Landslides_Overall         1117957.0   4.931376  2.078287   0.0   3.0   5.0
# Landslides_Lower_Outliers        0.0        NaN       NaN   NaN   NaN   NaN
# Landslides_Upper_Outliers     8865.0  11.561985  0.904648  11.0  11.0  11.0
#
#                             75%   max
# Landslides_Overall          6.0  16.0
# Landslides_Lower_Outliers   NaN   NaN
# Landslides_Upper_Outliers  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.826955                        0.0                   0.826955
#                                count       mean       std   min   25%   50%  \
# Watersheds_Overall         1117957.0   4.929032  2.082395   0.0   3.0   5.0
# Watersheds_Lower_Outliers        0.0        NaN       NaN   NaN   NaN   NaN
# Watersheds_Upper_Outliers     9245.0  11.590806  0.927897  11.0  11.0  11.0
#
#                             75%   max
# Watersheds_Overall          6.0  16.0
# Watersheds_Lower_Outliers   NaN   NaN
# Watersheds_Upper_Outliers  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.802446                        0.0                   0.802446
#                                                 count       mean       std  \
# DeterioratingInfrastructure_Overall         1117957.0   4.925907  2.064813
# DeterioratingInfrastructure_Lower_Outliers        0.0        NaN       NaN
# DeterioratingInfrastructure_Upper_Outliers     8971.0  11.544087  0.904917
#
#                                              min   25%   50%   75%   max
# DeterioratingInfrastructure_Overall          0.0   3.0   5.0   6.0  17.0
# DeterioratingInfrastructure_Lower_Outliers   NaN   NaN   NaN   NaN   NaN
# DeterioratingInfrastructure_Upper_Outliers  11.0  11.0  11.0  12.0  17.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0             0.83098                        0.0                    0.83098
#                                     count       mean       std   min   25%  \
# PopulationScore_Overall         1117957.0   4.927520  2.074176   0.0   3.0
# PopulationScore_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# PopulationScore_Upper_Outliers     9290.0  11.572121  0.916833  11.0  11.0
#
#                                  50%   75%   max
# PopulationScore_Overall          5.0   6.0  18.0
# PopulationScore_Lower_Outliers   NaN   NaN   NaN
# PopulationScore_Upper_Outliers  11.0  12.0  18.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            2.638652                   0.464419                   2.174234
#                                 count       mean       std   min   25%   50%  \
# WetlandLoss_Overall         1117957.0   4.950859  2.068696   0.0   4.0   5.0
# WetlandLoss_Lower_Outliers     5192.0   0.000000  0.000000   0.0   0.0   0.0
# WetlandLoss_Upper_Outliers    24307.0  10.588637  0.935987  10.0  10.0  10.0
#
#                              75%   max
# WetlandLoss_Overall          6.0  19.0
# WetlandLoss_Lower_Outliers   0.0   0.0
# WetlandLoss_Upper_Outliers  11.0  19.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.831785                        0.0                   0.831785
#                                        count       mean       std   min   25%  \
# InadequatePlanning_Overall         1117957.0   4.940587  2.081123   0.0   3.0
# InadequatePlanning_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# InadequatePlanning_Upper_Outliers     9299.0  11.576514  0.938889  11.0  11.0
#
#                                     50%   75%   max
# InadequatePlanning_Overall          5.0   6.0  16.0
# InadequatePlanning_Lower_Outliers   NaN   NaN   NaN
# InadequatePlanning_Upper_Outliers  11.0  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0             0.86828                        0.0                    0.86828
#                                      count       mean       std   min   25%  \
# PoliticalFactors_Overall         1117957.0   4.939004  2.090350   0.0   3.0
# PoliticalFactors_Lower_Outliers        0.0        NaN       NaN   NaN   NaN
# PoliticalFactors_Upper_Outliers     9707.0  11.520655  0.872137  11.0  11.0
#
#                                   50%   75%   max
# PoliticalFactors_Overall          5.0   6.0  16.0
# PoliticalFactors_Lower_Outliers   NaN   NaN   NaN
# PoliticalFactors_Upper_Outliers  11.0  12.0  16.0
#    Outlier Percentage  Lower Outliers Percentage  Upper Outliers Percentage
# 0            0.499035                   0.209489                   0.289546
#                                      count      mean       std    min    25%  \
# FloodProbability_Overall         1117957.0  0.504480  0.051026  0.285  0.470
# FloodProbability_Lower_Outliers     2342.0  0.348049  0.012780  0.285  0.345
# FloodProbability_Upper_Outliers     3237.0  0.662964  0.014993  0.650  0.655
#
#                                    50%    75%    max
# FloodProbability_Overall         0.505  0.540  0.725
# FloodProbability_Lower_Outliers  0.350  0.360  0.360
# FloodProbability_Upper_Outliers  0.660  0.665  0.725
